# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('train_exp2.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Wall time  120 non-null    float64
#  1   Step       120 non-null    int64
#  2   Value      120 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 2.9 KB

# %%
df.loc[:, 'Value']
# Out:
# 0      0.075
# 1      0.284
# 2      0.576
# 3      0.737
# 4      0.577
#        ...
# 115    0.990
# 116    0.989
# 117    0.991
# 118    0.992
# 119    0.991
# Name: Value, Length: 120, dtype: float64

# %%
working_df = df.iloc[:, 1:]

# %%
np.argmax(df.loc[:, 'Value'])
# Out:
# 91

# %%
sns.set_style('darkgrid')
ax = sns.lineplot(x='Step',y='Value',data=working_df)
ax.set(xlabel='Epochs', ylabel='Average Accuracy')
plt.show()
